# %% [markdown]
# ### Web Scraping for Liverpool vs Manchester City Matches at 3rd October, 2021
#
# The league’s best two teams for the last few years with two of the world’s best managers matched up on 3rd October 2021 to set up a pulsating encounter. In a breathtaking, enthralling Premier League on steroids classic we were reminded of the level Jurgen Klopp and Pep Guardiola have elevated not only both teams but the quality of the league in football’s current uber tactical environment.
#
# This has been deemed the blockbuster fixture to circle on calendars in recent years and never for a second did it disappoint, watching another chapter of two prime heavyweights unfold was fascinating. On many occasions last year perhaps because football was devoid of that oh so precious big-game atmosphere, the biggest games were a damp squib, but this clash was enrapturing.
#
# The reason why I scrape this match is that this game is one of the best matches in 2021. I got the dataset from <a href="https://understat.com/match/16441">understat.com</a>. So, let's get started it.

# %%
# Import necessary libraries

import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
# Scrape single game shot from understat.com

url = "https://understat.com/match/16441"

# %%
# Use requests to get the webpage and BeautifulSoup to parse the page

res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %%
# Get the shot data

strings = scripts[1].string

# %%
# Strip unnecessary symbols and get only json data
index_start = strings.index("('") + 2
index_end = strings.index("')")
json_data = strings[index_start:index_end]
json_data = json_data.encode('utf8').decode('unicode_escape')

# Convert string to json format
data = json.loads(json_data)
data
# Out:
# {'h': [{'id': '435650',
#    'minute': '7',
#    'result': 'BlockedShot',
#    'X': '0.8590000152587891',
#    'Y': '0.7319999694824219',
#    'xG': '0.028604544699192047',
#    'player': 'Mohamed Salah',
#    'h_a': 'h',
#    'player_id': '1250',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'James Milner',
#    'lastAction': 'Cross'},
#   {'id': '435658',
#    'minute': '49',
#    'result': 'SavedShot',
#    'X': '0.8380000305175781',
#    'Y': '0.5620000076293945',
#    'xG': '0.07208539545536041',
#    'player': 'Diogo Jota',
#    'h_a': 'h',
#    'player_id': '6854',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Joel Matip',
#    'lastAction': 'Pass'},
#   {'id': '435659',
#    'minute': '58',
#    'result': 'Goal',
#    'X': '0.8830000305175781',
#    'Y': '0.375',
#    'xG': '0.33443358540534973',
#    'player': 'Sadio Mané',
#    'h_a': 'h',
#    'player_id': '838',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Mohamed Salah',
#    'lastAction': 'Throughball'},
#   {'id': '435660',
#    'minute': '62',
#    'result': 'BlockedShot',
#    'X': '0.7519999694824219',
#    'Y': '0.6379999923706055',
#    'xG': '0.05370672792196274',
#    'player': 'Mohamed Salah',
#    'h_a': 'h',
#    'player_id': '1250',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '435663',
#    'minute': '75',
#    'result': 'Goal',
#    'X': '0.9669999694824218',
#    'Y': '0.36',
#    'xG': '0.16099528968334198',
#    'player': 'Mohamed Salah',
#    'h_a': 'h',
#    'player_id': '1250',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Curtis Jones',
#    'lastAction': 'TakeOn'},
#   {'id': '435666',
#    'minute': '86',
#    'result': 'BlockedShot',
#    'X': '0.9580000305175781',
#    'Y': '0.5979999923706054',
#    'xG': '0.29954251646995544',
#    'player': 'Fabinho',
#    'h_a': 'h',
#    'player_id': '3420',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Mohamed Salah',
#    'lastAction': 'Cross'}],
#  'a': [{'id': '435651',
#    'minute': '14',
#    'result': 'BlockedShot',
#    'X': '0.86',
#    'Y': '0.7230000305175781',
#    'xG': '0.033234648406505585',
#    'player': 'Jack Grealish',
#    'h_a': 'a',
#    'player_id': '675',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'João Cancelo',
#    'lastAction': 'Pass'},
#   {'id': '435652',
#    'minute': '20',
#    'result': 'SavedShot',
#    'X': '0.950999984741211',
#    'Y': '0.6120000076293945',
#    'xG': '0.3645058870315552',
#    'player': 'Phil Foden',
#    'h_a': 'a',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Throughball'},
#   {'id': '435653',
#    'minute': '23',
#    'result': 'MissedShots',
#    'X': '0.9219999694824219',
#    'Y': '0.6769999694824219',
#    'xG': '0.12026377022266388',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'a',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'João Cancelo',
#    'lastAction': 'Throughball'},
#   {'id': '435654',
#    'minute': '33',
#    'result': 'MissedShots',
#    'X': '0.9169999694824219',
#    'Y': '0.42700000762939455',
#    'xG': '0.08258016407489777',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'a',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Phil Foden',
#    'lastAction': 'Cross'},
#   {'id': '435655',
#    'minute': '37',
#    'result': 'BlockedShot',
#    'X': '0.8590000152587891',
#    'Y': '0.375',
#    'xG': '0.06337790191173553',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'a',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Gabriel Jesus',
#    'lastAction': 'Pass'},
#   {'id': '435656',
#    'minute': '39',
#    'result': 'BlockedShot',
#    'X': '0.86',
#    'Y': '0.33799999237060546',
#    'xG': '0.060323700308799744',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'a',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Gabriel Jesus',
#    'lastAction': 'Pass'},
#   {'id': '435657',
#    'minute': '39',
#    'result': 'MissedShots',
#    'X': '0.749000015258789',
#    'Y': '0.3820000076293945',
#    'xG': '0.024654502049088478',
#    'player': 'Rodri',
#    'h_a': 'a',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': None,
#    'lastAction': 'TakeOn'},
#   {'id': '435661',
#    'minute': '66',
#    'result': 'BlockedShot',
#    'X': '0.88',
#    'Y': '0.6880000305175781',
#    'xG': '0.03624071925878525',
#    'player': 'Gabriel Jesus',
#    'h_a': 'a',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Chipped'},
#   {'id': '435662',
#    'minute': '68',
#    'result': 'Goal',
#    'X': '0.9430000305175781',
#    'Y': '0.685',
#    'xG': '0.06177191808819771',
#    'player': 'Phil Foden',
#    'h_a': 'a',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Gabriel Jesus',
#    'lastAction': 'Pass'},
#   {'id': '435664',
#    'minute': '80',
#    'result': 'Goal',
#    'X': '0.8169999694824219',
#    'Y': '0.46700000762939453',
#    'xG': '0.0467507466673851',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'a',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '435665',
#    'minute': '83',
#    'result': 'MissedShots',
#    'X': '0.705999984741211',
#    'Y': '0.47900001525878905',
#    'xG': '0.040120746940374374',
#    'player': 'Kyle Walker',
#    'h_a': 'a',
#    'player_id': '638',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '435667',
#    'minute': '90',
#    'result': 'BlockedShot',
#    'X': '0.8730000305175781',
#    'Y': '0.35700000762939454',
#    'xG': '0.10936771333217621',
#    'player': 'Gabriel Jesus',
#    'h_a': 'a',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16441',
#    'h_team': 'Liverpool',
#    'a_team': 'Manchester City',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2021-10-03 15:30:00',
#    'player_assisted': 'Raheem Sterling',
#    'lastAction': 'Pass'}]}

# %%
Player = []
Minutes = []
Team = []
X = []
Y = []
ShotType = []
xG = []
Result = []
PlayerAssisted = []

data_home = data['h']
data_away = data['a']

# %%
for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'player':
            Player.append(data_home[index][key])
        if key == 'minute':
            Minutes.append(data_home[index][key])
        if key == 'h_team':
            Team.append(data_home[index][key])
        if key == 'X':
            X.append(data_home[index][key])
        if key == 'Y':
            Y.append(data_home[index][key])
        if key == 'shotType':
            ShotType.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            Result.append(data_home[index][key])
        if key == 'player_assisted':
            PlayerAssisted.append(data_home[index][key])
            
for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'player':
            Player.append(data_away[index][key])
        if key == 'minute':
            Minutes.append(data_away[index][key])
        if key == 'a_team':
            Team.append(data_away[index][key])
        if key == 'X':
            X.append(data_away[index][key])
        if key == 'Y':
            Y.append(data_away[index][key])
        if key == 'shotType':
            ShotType.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            Result.append(data_away[index][key])
        if key == 'player_assisted':
            PlayerAssisted.append(data_away[index][key])

# %%
# Create the DataFrame

column = ['Player', 'Minutes', 'Team', 'X', 'Y', 'Shot Type', 'xG', 'Result', 'Player Assisted']
df = pd.DataFrame([Player, Minutes, Team, X, Y, ShotType, xG, Result, PlayerAssisted], index = column).transpose()

# %%
df
# Out:
#              Player Minutes             Team                   X  \
# 0     Mohamed Salah       7        Liverpool  0.8590000152587891
# 1        Diogo Jota      49        Liverpool  0.8380000305175781
# 2        Sadio Mané      58        Liverpool  0.8830000305175781
# 3     Mohamed Salah      62        Liverpool  0.7519999694824219
# 4     Mohamed Salah      75        Liverpool  0.9669999694824218
# 5           Fabinho      86        Liverpool  0.9580000305175781
# 6     Jack Grealish      14  Manchester City                0.86
# 7        Phil Foden      20  Manchester City   0.950999984741211
# 8   Kevin De Bruyne      23  Manchester City  0.9219999694824219
# 9   Kevin De Bruyne      33  Manchester City  0.9169999694824219
# 10  Kevin De Bruyne      37  Manchester City  0.8590000152587891
# 11  Kevin De Bruyne      39  Manchester City                0.86
# 12            Rodri      39  Manchester City   0.749000015258789
# 13    Gabriel Jesus      66  Manchester City                0.88
# 14       Phil Foden      68  Manchester City  0.9430000305175781
# 15  Kevin De Bruyne      80  Manchester City  0.8169999694824219
# 16      Kyle Walker      83  Manchester City   0.705999984741211
# 17    Gabriel Jesus      90  Manchester City  0.8730000305175781
#
#                       Y  Shot Type                    xG       Result  \
# 0    0.7319999694824219   LeftFoot  0.028604544699192047  BlockedShot
# 1    0.5620000076293945   LeftFoot   0.07208539545536041    SavedShot
# 2                 0.375  RightFoot   0.33443358540534973         Goal
# 3    0.6379999923706055   LeftFoot   0.05370672792196274  BlockedShot
# 4                  0.36  RightFoot   0.16099528968334198         Goal
# 5    0.5979999923706054  RightFoot   0.29954251646995544  BlockedShot
# 6    0.7230000305175781  RightFoot  0.033234648406505585  BlockedShot
# 7    0.6120000076293945   LeftFoot    0.3645058870315552    SavedShot
# 8    0.6769999694824219   LeftFoot   0.12026377022266388  MissedShots
# 9   0.42700000762939455       Head   0.08258016407489777  MissedShots
# 10                0.375  RightFoot   0.06337790191173553  BlockedShot
# 11  0.33799999237060546   LeftFoot  0.060323700308799744  BlockedShot
# 12   0.3820000076293945  RightFoot  0.024654502049088478  MissedShots
# 13   0.6880000305175781  RightFoot   0.03624071925878525  BlockedShot
# 14                0.685   LeftFoot   0.06177191808819771         Goal
# 15  0.46700000762939453   LeftFoot    0.0467507466673851         Goal
# 16  0.47900001525878905  RightFoot  0.040120746940374374  MissedShots
# 17  0.35700000762939454  RightFoot   0.10936771333217621  BlockedShot
#
#     Player Assisted
# 0      James Milner
# 1        Joel Matip
# 2     Mohamed Salah
# 3              None
# 4      Curtis Jones
# 5     Mohamed Salah
# 6      João Cancelo
# 7    Bernardo Silva
# 8      João Cancelo
# 9        Phil Foden
# 10    Gabriel Jesus
# 11    Gabriel Jesus
# 12             None
# 13  Kevin De Bruyne
# 14    Gabriel Jesus
# 15             None
# 16             None
# 17  Raheem Sterling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Player           18 non-null     object
#  1   Minutes          18 non-null     object
#  2   Team             18 non-null     object
#  3   X                18 non-null     object
#  4   Y                18 non-null     object
#  5   Shot Type        18 non-null     object
#  6   xG               18 non-null     object
#  7   Result           18 non-null     object
#  8   Player Assisted  14 non-null     object
# dtypes: object(9)
# memory usage: 1.4+ KB

# %%
df['X'] = df['X'].astype(float).round(decimals = 3)
df['Y'] = df['Y'].astype(float).round(decimals = 3)
df['xG'] = df['xG'].astype(float).round(decimals = 3)
df['Minutes'] = df['Minutes'].astype(int)

# %%
df
# Out:
#              Player  Minutes             Team      X      Y  Shot Type     xG  \
# 0     Mohamed Salah        7        Liverpool  0.859  0.732   LeftFoot  0.029
# 1        Diogo Jota       49        Liverpool  0.838  0.562   LeftFoot  0.072
# 2        Sadio Mané       58        Liverpool  0.883  0.375  RightFoot  0.334
# 3     Mohamed Salah       62        Liverpool  0.752  0.638   LeftFoot  0.054
# 4     Mohamed Salah       75        Liverpool  0.967  0.360  RightFoot  0.161
# 5           Fabinho       86        Liverpool  0.958  0.598  RightFoot  0.300
# 6     Jack Grealish       14  Manchester City  0.860  0.723  RightFoot  0.033
# 7        Phil Foden       20  Manchester City  0.951  0.612   LeftFoot  0.365
# 8   Kevin De Bruyne       23  Manchester City  0.922  0.677   LeftFoot  0.120
# 9   Kevin De Bruyne       33  Manchester City  0.917  0.427       Head  0.083
# 10  Kevin De Bruyne       37  Manchester City  0.859  0.375  RightFoot  0.063
# 11  Kevin De Bruyne       39  Manchester City  0.860  0.338   LeftFoot  0.060
# 12            Rodri       39  Manchester City  0.749  0.382  RightFoot  0.025
# 13    Gabriel Jesus       66  Manchester City  0.880  0.688  RightFoot  0.036
# 14       Phil Foden       68  Manchester City  0.943  0.685   LeftFoot  0.062
# 15  Kevin De Bruyne       80  Manchester City  0.817  0.467   LeftFoot  0.047
# 16      Kyle Walker       83  Manchester City  0.706  0.479  RightFoot  0.040
# 17    Gabriel Jesus       90  Manchester City  0.873  0.357  RightFoot  0.109
#
#          Result  Player Assisted
# 0   BlockedShot     James Milner
# 1     SavedShot       Joel Matip
# 2          Goal    Mohamed Salah
# 3   BlockedShot             None
# 4          Goal     Curtis Jones
# 5   BlockedShot    Mohamed Salah
# 6   BlockedShot     João Cancelo
# 7     SavedShot   Bernardo Silva
# 8   MissedShots     João Cancelo
# 9   MissedShots       Phil Foden
# 10  BlockedShot    Gabriel Jesus
# 11  BlockedShot    Gabriel Jesus
# 12  MissedShots             None
# 13  BlockedShot  Kevin De Bruyne
# 14         Goal    Gabriel Jesus
# 15         Goal             None
# 16  MissedShots             None
# 17  BlockedShot  Raheem Sterling

# %%
df = df.sort_values(by = 'Minutes').reset_index()

# %%
df.drop(columns = 'index', inplace = True)
df
# Out:
#              Player  Minutes             Team      X      Y  Shot Type     xG  \
# 0     Mohamed Salah        7        Liverpool  0.859  0.732   LeftFoot  0.029
# 1     Jack Grealish       14  Manchester City  0.860  0.723  RightFoot  0.033
# 2        Phil Foden       20  Manchester City  0.951  0.612   LeftFoot  0.365
# 3   Kevin De Bruyne       23  Manchester City  0.922  0.677   LeftFoot  0.120
# 4   Kevin De Bruyne       33  Manchester City  0.917  0.427       Head  0.083
# 5   Kevin De Bruyne       37  Manchester City  0.859  0.375  RightFoot  0.063
# 6   Kevin De Bruyne       39  Manchester City  0.860  0.338   LeftFoot  0.060
# 7             Rodri       39  Manchester City  0.749  0.382  RightFoot  0.025
# 8        Diogo Jota       49        Liverpool  0.838  0.562   LeftFoot  0.072
# 9        Sadio Mané       58        Liverpool  0.883  0.375  RightFoot  0.334
# 10    Mohamed Salah       62        Liverpool  0.752  0.638   LeftFoot  0.054
# 11    Gabriel Jesus       66  Manchester City  0.880  0.688  RightFoot  0.036
# 12       Phil Foden       68  Manchester City  0.943  0.685   LeftFoot  0.062
# 13    Mohamed Salah       75        Liverpool  0.967  0.360  RightFoot  0.161
# 14  Kevin De Bruyne       80  Manchester City  0.817  0.467   LeftFoot  0.047
# 15      Kyle Walker       83  Manchester City  0.706  0.479  RightFoot  0.040
# 16          Fabinho       86        Liverpool  0.958  0.598  RightFoot  0.300
# 17    Gabriel Jesus       90  Manchester City  0.873  0.357  RightFoot  0.109
#
#          Result  Player Assisted
# 0   BlockedShot     James Milner
# 1   BlockedShot     João Cancelo
# 2     SavedShot   Bernardo Silva
# 3   MissedShots     João Cancelo
# 4   MissedShots       Phil Foden
# 5   BlockedShot    Gabriel Jesus
# 6   BlockedShot    Gabriel Jesus
# 7   MissedShots             None
# 8     SavedShot       Joel Matip
# 9          Goal    Mohamed Salah
# 10  BlockedShot             None
# 11  BlockedShot  Kevin De Bruyne
# 12         Goal    Gabriel Jesus
# 13         Goal     Curtis Jones
# 14         Goal             None
# 15  MissedShots             None
# 16  BlockedShot    Mohamed Salah
# 17  BlockedShot  Raheem Sterling

# %%
# Save into csv files

df.to_csv("Liverpool Shot vs Man City Shot.csv")
